# %% [markdown]
# # My First Program

# %%
1+1
# Out:
# 2

# %%
x = min(10,20,30)
y = max(10,20,30)

print(x)
print(y)
# Out:
# 10
# 30

# %%
x = pow(4,3)
print(x)
# Out:
# 64

# %%
import math

# %%
z = math.sqrt(9)
print(z)
# Out:
# 3.0
